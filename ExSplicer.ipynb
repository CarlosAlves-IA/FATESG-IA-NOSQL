# %% [markdown]
# # Exercicio
# Criar um programa em Python que recebe um nome completo de uma pessoa e:
# Conta quantos caracteres tem cada nome.
# Identifica a posição de cada nome dentro do nome completo.
# Reescreve cada nome de trás para frente.

# %%
nome_completo = input("Digite seu nome completo: ")
nomes = nome_completo.split()

print("-" * 30)
for i, nome in enumerate(nomes):
    print(f"Nome: {nome}")
    print(f"Quantidade de caracteres: {len(nome)}")
    print(f"Posição: {i + 1}º nome")
    print(f"Invertido: {nome[::-1]}")
    print("-" * 30)
# Out:
# ------------------------------
# Nome: CARLOS
# Quantidade de caracteres: 6
# Posição: 1º nome
# Invertido: SOLRAC
# ------------------------------
# Nome: HENRIQUE
# Quantidade de caracteres: 8
# Posição: 2º nome
# Invertido: EUQIRNEH
# ------------------------------
# Nome: RODRIGUES
# Quantidade de caracteres: 9
# Posição: 3º nome
# Invertido: SEUGIRDOR
# ------------------------------
# Nome: LACERDA
# Quantidade de caracteres: 7
# Posição: 4º nome
# Invertido: ADRECAL
# ------------------------------
# Nome: ALVES
# Quantidade de caracteres: 5
# Posição: 5º nome
# Invertido: SEVLA
# ------------------------------
